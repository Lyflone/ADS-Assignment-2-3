# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

# %%
Attrition_Data=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

Attrition_Data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
Attrition_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
Attrition_Data=Attrition_Data.dropna(how='all')

Attrition_Data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# Show a breakdown of distance from home by Job role and attrition

# %%
#attrition_data.groupby('JobRole', 'Attrition', axis=0)

df1=Attrition_Data.groupby(['DistanceFromHome', 'JobRole', 'Attrition' ]).first()
df1

plt.
# Out:
#                                                       Age     BusinessTravel  \
# DistanceFromHome JobRole                   Attrition
# 1                Healthcare Representative No          40  Travel_Frequently
#                  Human Resources           No          44      Travel_Rarely
#                                            Yes         44      Travel_Rarely
#                  Laboratory Technician     No          30  Travel_Frequently
#                                            Yes         48      Travel_Rarely
# ...                                                   ...                ...
# 29               Research Scientist        No          45      Travel_Rarely
#                                            Yes         33  Travel_Frequently
#                  Sales Executive           No          26      Travel_Rarely
#                                            Yes         26         Non-Travel
# ...

# %%
df2= Attrition_Data.groupby(['DistanceFromHome', 'JobRole', 'Education' ]).first()
# Out:
#                                                       Age Attrition  \
# DistanceFromHome JobRole                   Education
# 1                Healthcare Representative 1           45        No
#                                            2           49        No
#                                            3           46        No
#                                            4           40        No
#                  Human Resources           2           44       Yes
# ...                                                   ...       ...
# 29               Research Scientist        3           45        No
#                                            4           33       Yes
#                  Sales Executive           2           26        No
#                                            4           30        No
#                  Sales Representative      4           52        No
#
#                                                          BusinessTravel  \
# ...

# %%
Attrition_Data['AvMonthly_income']= Attrition_Data['MonthlyIncome'].mean()

Attrition_Data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# ...

# %%
Result=Attrition_Data.groupby(['AvMonthly_income', 'Education','Attrition' ]).first()

Result
# Out:
#                                       Age     BusinessTravel  DailyRate  \
# AvMonthly_income Education Attrition
# 6502.931293      1         No          49  Travel_Frequently        279
#                            Yes         34      Travel_Rarely        699
#                  2         No          32  Travel_Frequently       1005
#                            Yes         41      Travel_Rarely       1102
#                  3         No          59      Travel_Rarely       1324
#                            Yes         28      Travel_Rarely        103
#                  4         No          33  Travel_Frequently       1392
#                            Yes         36      Travel_Rarely       1218
#                  5         No          44      Travel_Rarely       1488
#                            Yes         29      Travel_Rarely        408
#
#                                                   Department  \
# AvMonthly_income Education Attrition
# ...

# %%
x=Attrition_Data['AvMonthly_income']
y=Attrition_Data['Education']
plt.bar(y,x)
plt.show()

# %%
x=Attrition_Data['AvMonthly_income']
y=Attrition_Data['Attrition']
plt.scatter(y,x)
plt.show()
